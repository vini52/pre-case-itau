# %% [markdown]
# <a href="https://colab.research.google.com/github/vini52/pre-case-itau/blob/main/pre_case_itau_teste_pagamento_tratamento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dados = pd.read_csv('/content/drive/MyDrive/pre-case-itau/pagamento.csv',
                    sep=';', encoding='UTF-8')
dados.head()

# %%
dados = dados.rename(columns={'ID Status Pagamento': 'id_status_pagamento', 'ID Empréstimo': 'id_emprestimo',
                              'Data de Pagamento': 'data_pagamento', 'Valor Pago': 'valor_pago', 'Status':'status_pagamento'})
dados.head()
# Out:
#    id_status_pagamento  id_emprestimo data_pagamento valor_pago  \
# 0                  201            101     15/03/2024     R$ 417
# 1                  202            102     05/04/2024   R$ 1.389
# 2                  203            103     26/03/2024     R$ 417
# 3                  204            104     31/03/2024     R$ 583
# 4                  205            105     10/04/2024     R$ 125
#
#   status_pagamento
# 0             Pago
# 1         Pendente
# 2             Pago
# 3         Pendente
# 4         Pendente

# %%
dados.dtypes
# Out:
# id_status_pagamento     int64
# id_emprestimo           int64
# data_pagamento         object
# valor_pago             object
# status_pagamento       object
# dtype: object

# %%
from decimal import Decimal
def converter_valor(valor_moeda):
  valor_formatado = valor_moeda.replace('R$', '').replace(' ', '')
  return Decimal(valor_formatado)
dados['valor_pago'] = dados['valor_pago'].apply(converter_valor)
dados.head()
# Out:
#    id_status_pagamento  id_emprestimo data_pagamento valor_pago  \
# 0                  201            101     15/03/2024        417
# 1                  202            102     05/04/2024      1.389
# 2                  203            103     26/03/2024        417
# 3                  204            104     31/03/2024        583
# 4                  205            105     10/04/2024        125
#
#   status_pagamento
# 0             Pago
# 1         Pendente
# 2             Pago
# 3         Pendente
# 4         Pendente

# %%
from datetime import datetime
def converter_data(data_string):
    return datetime.strptime(data_string, '%d/%m/%Y')
dados['data_pagamento'] = dados['data_pagamento'].apply(converter_data)
dados.head()
# Out:
#    id_status_pagamento  id_emprestimo data_pagamento valor_pago  \
# 0                  201            101     2024-03-15        417
# 1                  202            102     2024-04-05      1.389
# 2                  203            103     2024-03-26        417
# 3                  204            104     2024-03-31        583
# 4                  205            105     2024-04-10        125
#
#   status_pagamento
# 0             Pago
# 1         Pendente
# 2             Pago
# 3         Pendente
# 4         Pendente

# %%
dados.dtypes
# Out:
# id_status_pagamento             int64
# id_emprestimo                   int64
# data_pagamento         datetime64[ns]
# valor_pago                     object
# status_pagamento               object
# dtype: object

# %%
dados['status_pagamento'] = dados['status_pagamento'].replace({'Pago': True,'Pendente': False}).astype(bool)
dados.head()
# Out:
#    id_status_pagamento  id_emprestimo data_pagamento valor_pago  \
# 0                  201            101     2024-03-15        417
# 1                  202            102     2024-04-05      1.389
# 2                  203            103     2024-03-26        417
# 3                  204            104     2024-03-31        583
# 4                  205            105     2024-04-10        125
#
#    status_pagamento
# 0              True
# 1             False
# 2              True
# 3             False
# 4             False

# %%
dados.dtypes
# Out:
# id_status_pagamento             int64
# id_emprestimo                   int64
# data_pagamento         datetime64[ns]
# valor_pago                     object
# status_pagamento                 bool
# dtype: object

# %%
dados.to_csv('/content/drive/MyDrive/pre-case-itau/pagamento_tratado.csv', sep=';', encoding='UTF-8', index=False)
