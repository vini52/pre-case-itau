# %% [markdown]
# <a href="https://colab.research.google.com/github/vini52/pre-case-itau/blob/main/pre_case_itau_teste_residencia_tratamento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dados = pd.read_csv('/content/drive/MyDrive/pre-case-itau/residencia.csv',
                    sep=';', encoding='UTF-8')

# %%
dados.head()

# %%
dados = dados.rename(columns={'ID Residência': 'id_residencia', 'ID Cliente': 'id_cliente',
                              'Tipo de Residência': 'tipo_residencia', 'Endereço': 'endereco'})

# %%
dados.head()

# %%
dados['tipo_residencia'] = dados.tipo_residencia.str.upper()
dados['endereco'] = dados.endereco.str.upper()
dados.head()
# Out:
#    id_residencia  id_cliente tipo_residencia                          endereco
# 0            401           1         ALUGADA              RUA DOS TRILHOS, 457
# 1            402           2         PRÓPRIA  RUA DOMINGOS DE SANTA MARIA, 456
# 2            403           3         PRÓPRIA    RUA MANOEL FERNANDES LEÃO, 789
# 3            404           4         ALUGADA                 RUA PRETORIA, 124
# 4            405           5         PRÓPRIA                 AV. PAULISTA, 123

# %%
dados.to_csv('/content/drive/MyDrive/pre-case-itau/residencia_tratado.csv', sep=';', encoding='UTF-8', index=False)
